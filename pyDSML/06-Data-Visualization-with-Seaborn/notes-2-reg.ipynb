# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],
          scatter_kws={'s':100})
#scatter_kws, passes to matplotlib with dictionary, 's' for size

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',
          aspect=0.6,height=8)

# %%
import matplotlib.pyplot as plt

# %%
#sns.set_style('ticks') # <- some possible styles: white, ticks, darkgrid, whitegrid
#plt.figure(figsize=(12,3))
sns.set_context('notebook') # poster options and such, used for formatting
sns.countplot(x='sex',data=tips)
#sns.despine(left=True,bottom=True) 
# ^ Removes 'edges' (spines) of plot, defaut is Top and Right, bool param for L and B
# Can use seabourn without explicitly importing matplot lib?

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='seismic')
#more color maps avaliable by googling matplotlib colormaps
